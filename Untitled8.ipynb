# %% [markdown]
# <a href="https://colab.research.google.com/github/NikitaKrasnikov/Myproject/blob/new-feature/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ids = {'user1': [213, 213, 213, 15, 213],
       'user2': [54, 54, 119, 119, 119],
       'user3': [213, 98, 98, 35]}

unique_geotags = set()

for user_geotags in ids.values():
    unique_geotags.update(user_geotags)

print(unique_geotags)
# Out:
# {98, 35, 15, 213, 54, 119}
